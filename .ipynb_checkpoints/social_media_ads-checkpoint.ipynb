# %% [markdown]
# # Starting a project here on classification based on data taken from Kaggle at https://www.kaggle.com/datasets/rakeshrau/social-network-ads?resource=download
# # I should be quite clear that this is done on an accelerated time scale, so mistakes are likely to occur and the coding may not be to the best standard. Apologies, but this is intended to give what I think a code test would do: a quick and easy look at my style, how I structure my problem solving, and, of course, an answer in the end.

# %%
# !pip install xlrd
# !pip install scikit-learn --upgrade

# %%
#we're going to classify, so let's bring in our standard libraries, pandas and np, to get started. 

import pandas as pd
import numpy as np

#import the data as well
df = pd.read_excel('Social_Network_Ads.xls', engine='xlrd') ##how fun. the file dl's as xls so i'm just gonna rename the file and go from there
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       4 import numpy as np
#       6 #import the data as well
# ----> 7 df = pd.read_excel('Social_Network_Ads.xls', engine='xlrd')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
# ...

# %%
import os

old = 'Social_Network_Ads.xls'

new = 'Social_Network_Ads.csv'

os.rename(old, new)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 7
#       3 old = 'Social_Network_Ads.xls'
#       5 new = 'Social_Network_Ads.csv'
# ----> 7 os.rename(old, new)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Social_Network_Ads.xls' -> 'Social_Network_Ads.csv'

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#okay, what we have is a dataset of purchase binary, so, presumably a single product. We have uids, gender, age, and salary.
#Instead of deciding what type of algo to use, I think we'll just use them all and figure out what we want

from sklearn.model_selection import train_test_split
from sklearn.metrics import  f1_score, precision_score, accuracy_score,recall_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
##Using described to identify the characteristics of our 2 groups
df.groupby(['Purchased'])[['Age', 'Gender', 'EstimatedSalary']].describe()
# Out:
#              Age                                                     \
#            count       mean       std   min   25%   50%   75%   max
# Purchased
# 0          257.0  32.793774  7.985844  18.0  26.0  34.0  38.0  59.0
# 1          143.0  46.391608  8.612172  27.0  39.5  47.0  53.0  60.0
#
#           EstimatedSalary                                                \
#                     count          mean           std      min      25%
# Purchased
# 0                   257.0  60544.747082  24351.570102  15000.0  44000.0
# 1                   143.0  86272.727273  42064.200064  20000.0  41000.0
#
#
#                50%       75%       max
# Purchased
# 0          61000.0   77000.0  141000.0
# 1          90000.0  122500.0  150000.0

# %%
#standard notation of our x's and y's since I want to go straight into purchasing decisions we will call Purchased Y and X the rest

X = df.drop(columns=['Purchased'])
y = df[['Purchased']]

# %%
X
# Out:
#       User ID  Gender  Age  EstimatedSalary
# 0    15624510    Male   19            19000
# 1    15810944    Male   35            20000
# 2    15668575  Female   26            43000
# 3    15603246  Female   27            57000
# 4    15804002    Male   19            76000
# ..        ...     ...  ...              ...
# 395  15691863  Female   46            41000
# 396  15706071    Male   51            23000
# 397  15654296  Female   50            20000
# 398  15755018    Male   36            33000
# 399  15594041  Female   49            36000
#
# [400 rows x 4 columns]
